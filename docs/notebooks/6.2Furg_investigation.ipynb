# %%
import shutil
import os
import numpy as np

# %%
neg = os.listdir("/home/tomek/pro/aerial_fire_dataset/train/negatives")

# %%
to_move = np.random.choice(neg, int(0.1*len(neg)), replace=False)

# %%
for f in to_move:
    shutil.move("/home/tomek/pro/aerial_fire_dataset/train/negatives/"+f,
                "/home/tomek/pro/aerial_fire_dataset/test/negatives/")

# %%
# !ls
# Out:
#  1.0mRCNN_fire_inference.ipynb
#  2.0Binary_classifier_for_fire_recognition.ipynb
#  2.1VGG_binary_classifier_false_positive_and_negatives.ipynb
#  2.2VGG_binary_fire_model_dry_creek_inference.ipynb
#  3.0Visualizing_intermediate_activations.ipynb
#  3.1Visualizing_filters.ipynb
#  3.2VGG_monolith_model_training.ipynb
#  3.3grad_CAM.ipynb
#  3.4grad_CAM_on_mispredictions.ipynb
#  3_5_1EntireDryCreekGradCAM.ipynb
# '3.5grad_CAM_on_never_seen_data(DryCreek).ipynb'
# '3.5grad_CAM_on_never_seen_data(TestBurnSacramento).ipynb'
# '3.6grad_CAM_on_never_seen_data(SacramentoTestBurn).ipynb'
# '4.1CAM_grad_one_shot(SacramentoTestBurn).ipynb'
#  4.2.1Mosaic_on_ir+rgb.ipynb
#  4.2Mosaic.ipynb
#  5.0resnet_binary_pytorch.ipynb
# '5.2 image_split_into_3x3_grid.ipynb'
#  5.3.train-pytorch.ipynb
#  5.4.testing-pytorch.ipynb
#  6.0Dataset_stats.ipynb
#  6.1Count_params.ipynb
#  6.2Furg_investigation.ipynb
#  overhead.png

# %%
for f in pos:
    # !ls
# Out:
#  1.0mRCNN_fire_inference.ipynb
#  2.0Binary_classifier_for_fire_recognition.ipynb
#  2.1VGG_binary_classifier_false_positive_and_negatives.ipynb
#  2.2VGG_binary_fire_model_dry_creek_inference.ipynb
#  3.0Visualizing_intermediate_activations.ipynb
#  3.1Visualizing_filters.ipynb
#  3.2VGG_monolith_model_training.ipynb
#  3.3grad_CAM.ipynb
#  3.4grad_CAM_on_mispredictions.ipynb
#  3_5_1EntireDryCreekGradCAM.ipynb
# '3.5grad_CAM_on_never_seen_data(DryCreek).ipynb'
# '3.5grad_CAM_on_never_seen_data(TestBurnSacramento).ipynb'
# '3.6grad_CAM_on_never_seen_data(SacramentoTestBurn).ipynb'
# '4.1CAM_grad_one_shot(SacramentoTestBurn).ipynb'
#  4.2.1Mosaic_on_ir+rgb.ipynb
#  4.2Mosaic.ipynb
#  5.0resnet_binary_pytorch.ipynb
# '5.2 image_split_into_3x3_grid.ipynb'
#  5.3.train-pytorch.ipynb
#  5.4.testing-pytorch.ipynb
#  6.0Dataset_stats.ipynb
#  6.1Count_params.ipynb
#  6.1Furg_investigation.ipynb
#  overhead.png
#  1.0mRCNN_fire_inference.ipynb
# ...

# %%
len(pos)
# Out:
# 1005

# %%
mine
# Out:
# ['07056.jpg',
#  '00060.jpg',
#  '08361.jpg',
#  '08145.jpg',
#  '02596.jpg',
#  '03656.jpg',
#  '07807.jpg',
#  '00521.jpg',
#  '03996.jpg',
#  '07964.jpg',
#  '04120.jpg',
#  '00649.jpg',
#  '03976.jpg',
#  '05995.jpg',
#  '05201.jpg',
#  '07649.jpg',
#  '03465.jpg',
#  '01708.jpg',
#  '03636.jpg',
#  '05109.jpg',
#  '04085.jpg',
#  '09344.jpg',
#  '08863.jpg',
#  '01400.jpg',
#  '08884.jpg',
#  '03867.jpg',
#  '01641.jpg',
#  '09388.jpg',
#  '05399.jpg',
#  '03043.jpg',
#  '00597.jpg',
#  '03413.jpg',
#  '08344.jpg',
#  '01787.jpg',
#  '03321.jpg',
#  '03816.jpg',
#  '08650.jpg',
#  '02148.jpg',
#  '01854.jpg',
#  '01552.jpg',
#  '09195.jpg',
#  '04695.jpg',
#  '08002.jpg',
#  '06559.jpg',
#  '02934.jpg',
#  '03704.jpg',
#  '01047.jpg',
#  '04946.jpg',
#  '02144.jpg',
#  '07293.jpg',
#  '09397.jpg',
#  '04061.jpg',
#  '01705.jpg',
#  '01396.jpg',
#  '04625.jpg',
#  '00437.jpg',
#  '08080.jpg',
#  '03482.jpg',
#  '05566.jpg',
#  '07839.jpg',
#  '02454.jpg',
#  '07909.jpg',
# ...

# %%
aos.listdir("/home/tomek/pro/fire_aerial2k_dataset/")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-35-00dd0d2ed284> in <module>
# ----> 1 os.listdir("/home/tomek/pro/fire_aerial2k_dataset/")
#
# FileNotFoundError: [Errno 2] No such file or directory: '/home/tomek/pro/fire_aerial2k_dataset/'

# %%
dataset_paths = {
    "mine": "~/pro/fire_aerial2k_dataset/",
    "dunnings_train": "/media/tomek/BIG2/datasets/FIRE/dunnings/fire-dataset-dunnings/images-224x224/train_no_furg",
    "dunnings_test": "/media/tomek/BIG2/datasets/FIRE/dunnings/fire-dataset-dunnings/images-224x224/test",
    "furg_test": "/media/tomek/BIG2/datasets/FIRE/dunnings/fire-dataset-dunnings/images-224x224/test_furg/",
    "combo": "/home/tomek/pro/3datasets/",
}

# %%
import os

# %%
train = set(os.listdir("/media/tomek/BIG2/datasets/FIRE/dunnings/fire-dataset-dunnings/images-224x224/train/fire"))

# %%
furg_test = set(os.listdir("/media/tomek/BIG2/datasets/FIRE/dunnings/fire-dataset-dunnings/images-224x224/test_furg/fire"))

# %%
# !ls hand_held_camera_wildfire605.png
# Out:
# ls: cannot access 'hand_held_camera_wildfire605.png': No such file or directory

# %%
# !ls
# Out:
# furg  test  test_furg  train  train_no_furg

# %%
# !ls "/media/tomek/BIG2/datasets/FIRE/dunnings/fire-dataset-dunnings/images-224x224/train/fire/hand_held_camera_wildfire605.png"
# Out:
# /media/tomek/BIG2/datasets/FIRE/dunnings/fire-dataset-dunnings/images-224x224/train/fire/hand_held_camera_wildfire605.png

# %%
# !ls "/media/tomek/BIG2/datasets/FIRE/dunnings/fire-dataset-dunnings/images-224x224/test_furg/fire/hand_held_camera_wildfire605.png"
# Out:
# /media/tomek/BIG2/datasets/FIRE/dunnings/fire-dataset-dunnings/images-224x224/test_furg/fire/hand_held_camera_wildfire605.png

# %%
len(train.intersection(furg_test))
# Out:
# 7624
