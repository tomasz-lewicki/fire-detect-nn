# %%
import PIL 
from PIL import Image

# %%
from google.colab import drive
drive.mount('~/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /root/gdrive

# %%
# !ls '/root/gdrive/My Drive/SJSU_projects/Fire_for_Lab276/Test Burn August 7/RGB+IR_together.mp4'
# Out:
# '/root/gdrive/My Drive/SJSU_projects/Fire_for_Lab276/Test Burn August 7/RGB+IR_together.mp4'

# %%
# !ffmpeg -i '/root/gdrive/My Drive/SJSU_projects/Fire_for_Lab276/Test Burn August 7/RGB+IR_together.mp4' -vf fps=0.25 out%5d.jpg
# Out:
# ffmpeg version 3.4.6-0ubuntu0.18.04.1 Copyright (c) 2000-2019 the FFmpeg developers
#   built with gcc 7 (Ubuntu 7.3.0-16ubuntu3)
# ...

# %%
MASTER_SIZE_X = 3840*3
MASTER_SIZE_Y = 1080*3
TILES_N = 10
TILE_SIZE_X = int(MASTER_SIZE_X/TILES_N)
TILE_SIZE_Y = int(MASTER_SIZE_Y/TILES_N)

# %%
import os
DIR = 'images/'
ls = os.listdir(DIR)

# %%
image = Image.new('RGB', (MASTER_SIZE_X, MASTER_SIZE_Y))
idx = 0
for x in range(0, MASTER_SIZE_X, TILE_SIZE_X):
    for y in range(0, MASTER_SIZE_Y, TILE_SIZE_Y):
        print("image:", idx)
        tile = Image.open(DIR+ls[idx])
        tile_smol = tile.resize((TILE_SIZE_X,TILE_SIZE_Y))
        image.paste(tile_smol, (x, y))
        idx += 1
# Out:
# image: 0
# image: 1
# image: 2
# image: 3
# image: 4
# image: 5
# image: 6
# image: 7
# image: 8
# image: 9
# image: 10
# image: 11
# image: 12
# image: 13
# image: 14
# image: 15
# image: 16
# image: 17
# image: 18
# image: 19
# image: 20
# image: 21
# image: 22
# image: 23
# image: 24
# image: 25
# image: 26
# image: 27
# image: 28
# image: 29
# image: 30
# image: 31
# image: 32
# image: 33
# image: 34
# image: 35
# image: 36
# image: 37
# image: 38
# image: 39
# image: 40
# image: 41
# image: 42
# image: 43
# image: 44
# image: 45
# image: 46
# image: 47
# image: 48
# image: 49
# image: 50
# image: 51
# image: 52
# image: 53
# image: 54
# image: 55
# image: 56
# image: 57
# image: 58
# image: 59
# image: 60
# image: 61
# image: 62
# image: 63
# image: 64
# image: 65
# image: 66
# image: 67
# image: 68
# image: 69
# image: 70
# image: 71
# image: 72
# image: 73
# image: 74
# image: 75
# image: 76
# image: 77
# image: 78
# image: 79
# image: 80
# image: 81
# image: 82
# image: 83
# ...

# %%
name = str(MASTER_SIZE_X)+'X'+str(MASTER_SIZE_Y)+'tilesize'+str(TILE_SIZE_X)+'X'+str(TILE_SIZE_Y)

image.save(name+'.jpg')

# %%
import matplotlib.pyplot as plt
plt.imshow(image)

# %%
image.save("/root/gdrive/My Drive/SJSU_projects/Fire_for_Lab276/Test Burn August 7/mosaic/"+name+'.jpg')

# %%
# !mkdir '/root/gdrive/My Drive/SJSU_projects/Fire_for_Lab276/Test Burn August 7/mosaic'
